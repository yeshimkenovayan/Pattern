# %%
import pandas as pd
oper = pd.read_csv('D:/pattern/lab2/1 - operations.csv',sep=',')
ds = pd.read_csv('D:/pattern/lab2/2 - dataset.csv',sep=',')
ttypes = pd.read_csv('D:/pattern/lab2/3 - types.csv',sep=';')
codes = pd.read_csv('D:/pattern/lab2/4 - codes.csv',sep=';')
oper[:3]
# Out:
#    client_id      datetime  code  type        sum source_id
# 0   96372458  421 06:33:15  6011  2010 -561478.94    256572
# 1   64404394  399 06:56:49  6011  2010  -67377.47    330228
# 2   24567813  377 17:20:40  6011  7010   67377.47    542191

# %%
import pandas as pd
oper = pd.read_csv('D:/pattern/lab2/1 - operations.csv',sep=',')
ds = pd.read_csv('D:/pattern/lab2/2 - dataset.csv',sep=',')
ttypes = pd.read_csv('D:/pattern/lab2/3 - types.csv',sep=';')
codes = pd.read_csv('D:/pattern/lab2/4 - codes.csv',sep=';')
oper[:3]
ds[:3]
ttypes[:3]
codes[:5]
# Out:
#    code                                   code_description
# 0  5944  Магазины по продаже часов, ювелирных изделий и...
# 1  5621                             Готовая женская одежда
# 2  5697       Услуги по переделке, починке и пошиву одежды
# 3  7995                       Транзакции по азартным играм
# 4  5137             Мужская, женская и детская спец-одежда

# %%
import pandas as pd
oper = pd.read_csv('D:/pattern/lab2/1 - operations.csv',sep=',')
ds = pd.read_csv('D:/pattern/lab2/2 - dataset.csv',sep=',')
ttypes = pd.read_csv('D:/pattern/lab2/3 - types.csv',sep=';')
codes = pd.read_csv('D:/pattern/lab2/4 - codes.csv',sep=';')
ttypes[:3]
# Out:
#    type                                   type_description
# 0  8001                      Установление расх. лимита по
# 1  2411  Перевод с карты на счет др.лица в одном тер. б...
# 2  4035                                                н/д

# %%
import pandas as pd
oper = pd.read_csv('D:/pattern/lab2/1 - operations.csv',sep=',')
ds = pd.read_csv('D:/pattern/lab2/2 - dataset.csv',sep=',')
ttypes = pd.read_csv('D:/pattern/lab2/3 - types.csv',sep=';')
codes = pd.read_csv('D:/pattern/lab2/4 - codes.csv',sep=';')
ds[:3]
# Out:
#    client_id  status
# 0   31984797       1
# 1   95623488       1
# 2   21248516       1

# %%
table1 = pd.merge(oper,ds, on='client_id')
table2 = pd.merge(table1, ttypes, on='type')
table3 = pd.merge(table2, codes, on='code')
print(table1)
# Out:
#          client_id      datetime  code  type         sum source_id  status
# 0         96372458  421 06:33:15  6011  2010  -561478.94    256572       0
# 1         96372458  270 06:16:18  6011  7010   224591.58    368340       0
# 2         96372458   97 10:48:35  4829  2370   -11229.58       NaN       0
# 3         96372458  445 07:33:38  4829  2330  -417695.42    368340       0
# 4         96372458    4 09:33:46  4814  1030    -2245.92       NaN       0
# 5         96372458  316 23:42:38  4814  1030    -1122.96    888996       0
# 6         96372458   68 02:04:11  6011  2010  -426724.00       NaN       0
# 7         96372458  448 11:07:35  4814  1030    -2245.92    888995       0
# 8         96372458  295 08:16:07  4814  1030   -11229.58    888984       0
# 9         96372458  126 10:13:01  4814  1030    -1235.25       NaN       0
# 10        96372458  129 05:34:06  6010  7030   224591.58       NaN       0
# ...

# %%
table1 = pd.merge(oper,ds, on='client_id')
table2 = pd.merge(table1, ttypes, on='type')
table3 = pd.merge(table2, codes, on='code')
print(table2)
print(table3)
# Out:
#          client_id      datetime  code  type         sum  source_id  status  \
# 0         96372458  421 06:33:15  6011  2010  -561478.94     256572       0
# 1         96372458   68 02:04:11  6011  2010  -426724.00        NaN       0
# 2         96372458  433 06:45:32  6011  2010  -112295.79     256566       0
# 3         96372458  314 01:18:44  6011  2010 -1122957.89     256566       0
# 4         96372458  350 01:09:16  6011  2010 -1100498.73     256566       0
# 5         96372458  445 07:35:23  6011  2010  -494101.47     256566       0
# 6         96372458  396 07:48:53  6011  2010  -101066.21     256566       0
# 7         96372458  430 06:29:50  6011  2010  -224591.58     256566       0
# 8         96372458   25 06:58:51  6011  2010   -78607.05        NaN       0
# 9         96372458  421 01:56:12  6011  2010  -314428.21     581606       0
# 10        96372458  278 04:04:05  6011  2010  -179673.26     581606       0
# ...

# %%
import matplotlib.pyplot as plt
table3[table3['client_id']>61500000][table3['client_id']<81500000]['client_id'].hist(bins=50,color = 'teal')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
import matplotlib.pyplot as plt
table3[table3['sum'].hist(bins=50,color = 'red')
plt.show()
# Out:
#   File "<ipython-input-16-28a300f13c9f>", line 3
#     plt.show()
#       ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
table3[table3['code'].hist(bins=50,color = 'blue')
plt.show()
# Out:
#   File "<ipython-input-17-634fa92f55fd>", line 3
#     plt.show()
#       ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
table3[table3['type'].hist(bins=50,color = 'green')
plt.show()
# Out:
#   File "<ipython-input-18-6cf772746ed6>", line 3
#     plt.show()
#       ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
table3[table3['status'].hist(bins=50,color = 'yellow')
plt.show()
# Out:
#   File "<ipython-input-19-c619b0eb7c70>", line 3
#     plt.show()
#       ^
# SyntaxError: invalid syntax
